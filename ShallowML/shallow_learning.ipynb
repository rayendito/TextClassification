# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import nltk
import re

# %%
train = pd.read_csv('../data_worthcheck/train.csv', index_col=0)
test = pd.read_csv('../data_worthcheck/test.csv')
dev = pd.read_csv('../data_worthcheck/dev.csv')

# %%
print(train.info())
print(test.info())
print(dev.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21601 entries, 0 to 21600
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text_a  21601 non-null  object
#  1   label   21601 non-null  object
# dtypes: object(2)
# memory usage: 506.3+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2800 entries, 0 to 2799
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text_a  2800 non-null   object
#  1   label   2800 non-null   object
# dtypes: object(2)
# memory usage: 43.9+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2800 entries, 0 to 2799
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text_a  2800 non-null   object
#  1   label   2800 non-null   object
# dtypes: object(2)
# memory usage: 43.9+ KB
# None

# %% [markdown]
# # Preprocessing
#
# 1. Casefolding
# 2. Remove Non Alphabet (Numbers, Punctuation)
# 3. Tfidf Vectorizer

# %%
def preprocess(col):
    col_copy = col.copy()
    col_copy = col_copy.str.lower()
    col_copy = col_copy.str.replace(r'[^a-z\s]', ' ', regex=True)
    col_copy = col_copy.str.replace(r'\s+', ' ', regex=True).str.strip()
    # drop with len == 0
    col_copy = col_copy[col_copy.str.len() > 0]
    return col_copy

# %%
train_preprocessed_text = preprocess(train['text_a'])
test_preprocessed_text = preprocess(test['text_a'])
dev_preprocessed_text = preprocess(dev['text_a'])

label_train = train.loc[train_preprocessed_text.index, 'label']
label_test = test.loc[test_preprocessed_text.index, 'label']
label_dev = dev.loc[dev_preprocessed_text.index, 'label']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vect = TfidfVectorizer(analyzer='word',ngram_range=(1,1))
X_train = vect.fit_transform(train_preprocessed_text)
X_test = vect.transform(test_preprocessed_text)
X_dev = vect.transform(dev_preprocessed_text)

# %%
# encode label
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y_train = le.fit_transform(label_train)
y_test = le.transform(label_test)
y_dev = le.transform(label_dev)

# %% [markdown]
# # Naive Bayes

# %%
# naive bayes
from sklearn.naive_bayes import MultinomialNB
nb = MultinomialNB()
nb.fit(X_train, y_train)
# Out:
# MultinomialNB()

# %% [markdown]
# # SVM

# %%
# svm
from sklearn.svm import SVC
svm = SVC(kernel='rbf', C=1.0, random_state=0)
svm.fit(X_train, y_train)
# Out:
# SVC(random_state=0)

# %% [markdown]
# # XGBoost

# %%
# xgboost
from xgboost import XGBClassifier
xgb = XGBClassifier()
xgb.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0, reg_lambda=1, ...)

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

dt = DecisionTreeClassifier()
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier()
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression()
lr.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# # Evaluation

# %%
# f1 score
from sklearn.metrics import f1_score

print('Naive Bayes')
print(f1_score(y_test, nb.predict(X_test)))
print('SVM')
print(f1_score(y_dev, svm.predict(X_dev)))
print('XGBoost')
print(f1_score(y_dev, xgb.predict(X_dev)))
print('Decision Tree')
print(f1_score(y_dev, dt.predict(X_dev)))
print('Random Forest')
print(f1_score(y_dev, rf.predict(X_dev)))
print('Logistic Regression')
print(f1_score(y_dev, lr.predict(X_dev)))
# Out:
# Naive Bayes
# 0.5962264150943396
# SVM
# 0.7268588770864947
# XGBoost
# 0.6374501992031872
# Decision Tree
# 0.5960890087660149
# Random Forest
# 0.6683459277917716
# Logistic Regression
# 0.6961240310077519

# %% [markdown]
# # Grid Search

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline

parameters = [
    {
        'vect__ngram_range': [(1, 1), (1, 2), (2, 2)],
        'vect__analyzer': ['word', 'char', 'char_wb'],
        'clf__alpha': [0.1, 1.0, 10.0],
    },
    # {
    #     'clf': [SVC()],
    #     'vect__ngram_range': [(1, 1), (1, 2), (2, 2)],
    #     'vect__analyzer': ['word', 'char', 'char_wb'],
    #     'clf__kernel': ['poly', 'rbf'],
    #     'clf__degree': [2, 3, 4],
    #     'clf__C': [0.1, 1.0, 10.0],
    # },
    {
        'clf': [XGBClassifier()],
        'vect__ngram_range': [(1, 1), (1, 2), (2, 2)],
        'vect__analyzer': ['word', 'char', 'char_wb'],
        'clf__max_depth': [3, 4, 5],
        'clf__learning_rate': [0.1, 0.2, 0.3],
        'clf__n_estimators': [100, 200, 300],
    },
    {
        'clf': [DecisionTreeClassifier()],
        'vect__ngram_range': [(1, 1), (1, 2), (2, 2)],
        'vect__analyzer': ['word', 'char', 'char_wb'],
        'clf__max_depth': [3, 4, 5],
        'clf__min_samples_split': [2, 3, 4],
        'clf__min_samples_leaf': [1, 2, 3],
    },
    {
        'clf': [RandomForestClassifier()],
        'vect__ngram_range': [(1, 1), (1, 2), (2, 2)],
        'vect__analyzer': ['word', 'char', 'char_wb'],
        'clf__max_depth': [3, 4, 5],
        'clf__min_samples_split': [2, 3, 4],
        'clf__min_samples_leaf': [1, 2, 3],
        'clf__n_estimators': [100, 200, 300],
    },
    {
        'clf': [LogisticRegression()],
        'vect__ngram_range': [(1, 1), (1, 2), (2, 2)],
        'vect__analyzer': ['word', 'char', 'char_wb'],
        'clf__penalty': ['l1', 'l2'],
        'clf__C': [0.1, 1.0, 10.0],
    },
]

# %%
from sklearn.model_selection import PredefinedSplit

train_fold = [-1 for _ in range(len(train_preprocessed_text))]
dev_fold = [0 for _ in range(len(dev_preprocessed_text))]
ps = PredefinedSplit(test_fold=np.concatenate([train_fold, dev_fold]))

X = pd.concat([train_preprocessed_text, dev_preprocessed_text]).reset_index(drop=True)
y = np.concatenate([y_train, y_dev])

# %%
for train_index, test_index in ps.split():
    # dev and test are the same
    assert any(X.loc[test_index].reset_index(drop=True) == test_preprocessed_text)
    assert any(y[test_index] == y_test)
    assert any(X.loc[test_index].reset_index(drop=True) == dev_preprocessed_text)
    assert any(y[test_index] == y_dev)

# %%
# gridsearch
# score f1
gs = GridSearchCV(Pipeline([('vect', TfidfVectorizer()),('clf', MultinomialNB())]), parameters, cv=ps, scoring='f1',verbose=3)
gs.fit(X, y)
# Out:
# Fitting 1 folds for each of 1296 candidates, totalling 1296 fits
# [CV 1/1] END clf__alpha=0.1, vect__analyzer=word, vect__ngram_range=(1, 1);, score=0.693 total time=   0.2s
# [CV 1/1] END clf__alpha=0.1, vect__analyzer=word, vect__ngram_range=(1, 2);, score=0.728 total time=   0.7s
# [CV 1/1] END clf__alpha=0.1, vect__analyzer=word, vect__ngram_range=(2, 2);, score=0.672 total time=   0.5s
# [CV 1/1] END clf__alpha=0.1, vect__analyzer=char, vect__ngram_range=(1, 1);, score=0.000 total time=   0.3s
# [CV 1/1] END clf__alpha=0.1, vect__analyzer=char, vect__ngram_range=(1, 2);, score=0.173 total time=   1.1s
# [CV 1/1] END clf__alpha=0.1, vect__analyzer=char, vect__ngram_range=(2, 2);, score=0.305 total time=   0.7s
# [CV 1/1] END clf__alpha=0.1, vect__analyzer=char_wb, vect__ngram_range=(1, 1);, score=0.000 total time=   0.8s
# [CV 1/1] END clf__alpha=0.1, vect__analyzer=char_wb, vect__ngram_range=(1, 2);, score=0.096 total time=   1.7s
# [CV 1/1] END clf__alpha=0.1, vect__analyzer=char_wb, vect__ngram_range=(2, 2);, score=0.305 total time=   0.9s
# [CV 1/1] END clf__alpha=1.0, vect__analyzer=word, vect__ngram_range=(1, 1);, score=0.596 total time=   0.2s
# [CV 1/1] END clf__alpha=1.0, vect__analyzer=word, vect__ngram_range=(1, 2);, score=0.572 total time=   0.7s
# [CV 1/1] END clf__alpha=1.0, vect__analyzer=word, vect__ngram_range=(2, 2);, score=0.571 total time=   0.5s
# [CV 1/1] END clf__alpha=1.0, vect__analyzer=char, vect__ngram_range=(1, 1);, score=0.000 total time=   0.3s
# [CV 1/1] END clf__alpha=1.0, vect__analyzer=char, vect__ngram_range=(1, 2);, score=0.173 total time=   1.1s
# [CV 1/1] END clf__alpha=1.0, vect__analyzer=char, vect__ngram_range=(2, 2);, score=0.291 total time=   0.7s
# [CV 1/1] END clf__alpha=1.0, vect__analyzer=char_wb, vect__ngram_range=(1, 1);, score=0.000 total time=   0.8s
# [CV 1/1] END clf__alpha=1.0, vect__analyzer=char_wb, vect__ngram_range=(1, 2);, score=0.096 total time=   1.7s
# [CV 1/1] END clf__alpha=1.0, vect__analyzer=char_wb, vect__ngram_range=(2, 2);, score=0.297 total time=   0.9s
# [CV 1/1] END clf__alpha=10.0, vect__analyzer=word, vect__ngram_range=(1, 1);, score=0.120 total time=   0.2s
# [CV 1/1] END clf__alpha=10.0, vect__analyzer=word, vect__ngram_range=(1, 2);, score=0.076 total time=   0.7s
# [CV 1/1] END clf__alpha=10.0, vect__analyzer=word, vect__ngram_range=(2, 2);, score=0.063 total time=   0.5s
# [CV 1/1] END clf__alpha=10.0, vect__analyzer=char, vect__ngram_range=(1, 1);, score=0.000 total time=   0.3s
# [CV 1/1] END clf__alpha=10.0, vect__analyzer=char, vect__ngram_range=(1, 2);, score=0.075 total time=   1.1s
# [CV 1/1] END clf__alpha=10.0, vect__analyzer=char, vect__ngram_range=(2, 2);, score=0.180 total time=   0.7s
# [CV 1/1] END clf__alpha=10.0, vect__analyzer=char_wb, vect__ngram_range=(1, 1);, score=0.000 total time=   0.8s
# [CV 1/1] END clf__alpha=10.0, vect__analyzer=char_wb, vect__ngram_range=(1, 2);, score=0.031 total time=   1.7s
# [CV 1/1] END clf__alpha=10.0, vect__analyzer=char_wb, vect__ngram_range=(2, 2);, score=0.175 total time=   0.9s
# [CV 1/1] END clf=XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, gamma=None,
#               gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, predictor=None, random_state=None,
#               reg_alpha=None, reg_lambda=None, ...), clf__learning_rate=0.1, clf__max_depth=3, clf__n_estimators=100, vect__analyzer=word, vect__ngram_range=(1, 1);, score=0.520 total time=   0.7s
# [CV 1/1] END clf=XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, gamma=None,
#               gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, predictor=None, random_state=None,
#               reg_alpha=None, reg_lambda=None, ...), clf__learning_rate=0.1, clf__max_depth=3, clf__n_estimators=100, vect__analyzer=word, vect__ngram_range=(1, 2);, score=0.527 total time=   2.0s
# [CV 1/1] END clf=XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, gamma=None,
#               gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, predictor=None, random_state=None,
#               reg_alpha=None, reg_lambda=None, ...), clf__learning_rate=0.1, clf__max_depth=3, clf__n_estimators=100, vect__analyzer=word, vect__ngram_range=(2, 2);, score=0.442 total time=   1.2s
# [CV 1/1] END clf=XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, gamma=None,
#               gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, predictor=None, random_state=None,
#               reg_alpha=None, reg_lambda=None, ...), clf__learning_rate=0.1, clf__max_depth=3, clf__n_estimators=100, vect__analyzer=char, vect__ngram_range=(1, 1);, score=0.447 total time=   1.3s
# [CV 1/1] END clf=XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, gamma=None,
#               gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, predictor=None, random_state=None,
#               reg_alpha=None, reg_lambda=None, ...), clf__learning_rate=0.1, clf__max_depth=3, clf__n_estimators=100, vect__analyzer=char, vect__ngram_range=(1, 2);, score=0.563 total time=   4.1s
# [CV 1/1] END clf=XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, gamma=None,
#               gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, predictor=None, random_state=None,
#               reg_alpha=None, reg_lambda=None, ...), clf__learning_rate=0.1, clf__max_depth=3, clf__n_estimators=100, vect__analyzer=char, vect__ngram_range=(2, 2);, score=0.564 total time=   3.1s
# [CV 1/1] END clf=XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, gamma=None,
#               gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, predictor=None, random_state=None,
#               reg_alpha=None, reg_lambda=None, ...), clf__learning_rate=0.1, clf__max_depth=3, clf__n_estimators=100, vect__analyzer=char_wb, vect__ngram_range=(1, 1);, score=0.440 total time=   1.7s
# [CV 1/1] END clf=XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, gamma=None,
#               gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, predictor=None, random_state=None,
#               reg_alpha=None, reg_lambda=None, ...), clf__learning_rate=0.1, clf__max_depth=3, clf__n_estimators=100, vect__analyzer=char_wb, vect__ngram_range=(1, 2);, score=0.567 total time=   4.7s
# [CV 1/1] END clf=XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, gamma=None,
#               gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, predictor=None, random_state=None,
#               reg_alpha=None, reg_lambda=None, ...), clf__learning_rate=0.1, clf__max_depth=3, clf__n_estimators=100, vect__analyzer=char_wb, vect__ngram_range=(2, 2);, score=0.569 total time=   3.3s
# [CV 1/1] END clf=XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, gamma=None,
#               gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, predictor=None, random_state=None,
#               reg_alpha=None, reg_lambda=None, ...), clf__learning_rate=0.1, clf__max_depth=3, clf__n_estimators=200, vect__analyzer=word, vect__ngram_range=(1, 1);, score=0.585 total time=   1.3s
# [CV 1/1] END clf=XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, gamma=None,
#               gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, predictor=None, random_state=None,
#               reg_alpha=None, reg_lambda=None, ...), clf__learning_rate=0.1, clf__max_depth=3, clf__n_estimators=200, vect__analyzer=word, vect__ngram_range=(1, 2);, score=0.590 total time=   3.0s
# [CV 1/1] END clf=XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, gamma=None,
#               gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, predictor=None, random_state=None,
#               reg_alpha=None, reg_lambda=None, ...), clf__learning_rate=0.1, clf__max_depth=3, clf__n_estimators=200, vect__analyzer=word, vect__ngram_range=(2, 2);, score=0.472 total time=   1.7s
# [CV 1/1] END clf=XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, gamma=None,
#               gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, predictor=None, random_state=None,
#               reg_alpha=None, reg_lambda=None, ...), clf__learning_rate=0.1, clf__max_depth=3, clf__n_estimators=200, vect__analyzer=char, vect__ngram_range=(1, 1);, score=0.483 total time=   2.2s
# [CV 1/1] END clf=XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, gamma=None,
#               gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, predictor=None, random_state=None,
#               reg_alpha=None, reg_lambda=None, ...), clf__learning_rate=0.1, clf__max_depth=3, clf__n_estimators=200, vect__analyzer=char, vect__ngram_range=(1, 2);, score=0.600 total time=   7.0s
# [CV 1/1] END clf=XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, gamma=None,
#               gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, predictor=None, random_state=None,
#               reg_alpha=None, reg_lambda=None, ...), clf__learning_rate=0.1, clf__max_depth=3, clf__n_estimators=200, vect__analyzer=char, vect__ngram_range=(2, 2);, score=0.593 total time=   5.3s
# [CV 1/1] END clf=XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, gamma=None,
#               gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, predictor=None, random_state=None,
#               reg_alpha=None, reg_lambda=None, ...), clf__learning_rate=0.1, clf__max_depth=3, clf__n_estimators=200, vect__analyzer=char_wb, vect__ngram_range=(1, 1);, score=0.472 total time=   2.6s
# [CV 1/1] END clf=XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, gamma=None,
#               gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, predictor=None, random_state=None,
#               reg_alpha=None, reg_lambda=None, ...), clf__learning_rate=0.1, clf__max_depth=3, clf__n_estimators=200, vect__analyzer=char_wb, vect__ngram_range=(1, 2);, score=0.612 total time=   7.7s
# [CV 1/1] END clf=XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, gamma=None,
#               gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, predictor=None, random_state=None,
#               reg_alpha=None, reg_lambda=None, ...), clf__learning_rate=0.1, clf__max_depth=3, clf__n_estimators=200, vect__analyzer=char_wb, vect__ngram_range=(2, 2);, score=0.600 total time=   5.6s
# [CV 1/1] END clf=XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, gamma=None,
#               gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, predictor=None, random_state=None,
#               reg_alpha=None, reg_lambda=None, ...), clf__learning_rate=0.1, clf__max_depth=3, clf__n_estimators=300, vect__analyzer=word, vect__ngram_range=(1, 1);, score=0.598 total time=   1.8s
# [CV 1/1] END clf=XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, gamma=None,
#               gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, predictor=None, random_state=None,
#               reg_alpha=None, reg_lambda=None, ...), clf__learning_rate=0.1, clf__max_depth=3, clf__n_estimators=300, vect__analyzer=word, vect__ngram_range=(1, 2);, score=0.596 total time=   4.0s
# [CV 1/1] END clf=XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, gamma=None,
#               gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, predictor=None, random_state=None,
#               reg_alpha=None, reg_lambda=None, ...), clf__learning_rate=0.1, clf__max_depth=3, clf__n_estimators=300, vect__analyzer=word, vect__ngram_range=(2, 2);, score=0.487 total time=   2.2s
# [CV 1/1] END clf=XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, gamma=None,
#               gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, predictor=None, random_state=None,
#               reg_alpha=None, reg_lambda=None, ...), clf__learning_rate=0.1, clf__max_depth=3, clf__n_estimators=300, vect__analyzer=char, vect__ngram_range=(1, 1);, score=0.498 total time=   3.0s
# [CV 1/1] END clf=XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, gamma=None,
#               gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, predictor=None, random_state=None,
#               reg_alpha=None, reg_lambda=None, ...), clf__learning_rate=0.1, clf__max_depth=3, clf__n_estimators=300, vect__analyzer=char, vect__ngram_range=(1, 2);, score=0.627 total time=   9.8s
# [CV 1/1] END clf=XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, gamma=None,
#               gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, predictor=None, random_state=None,
#               reg_alpha=None, reg_lambda=None, ...), clf__learning_rate=0.1, clf__max_depth=3, clf__n_estimators=300, vect__analyzer=char, vect__ngram_range=(2, 2);, score=0.619 total time=   7.5s
# [CV 1/1] END clf=XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, gamma=None,
#               gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, predictor=None, random_state=None,
#               reg_alpha=None, reg_lambda=None, ...), clf__learning_rate=0.1, clf__max_depth=3, clf__n_estimators=300, vect__analyzer=char_wb, vect__ngram_range=(1, 1);, score=0.498 total time=   3.5s
# [CV 1/1] END clf=XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, gamma=None,
#               gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, predictor=None, random_state=None,
#               reg_alpha=None, reg_lambda=None, ...), clf__learning_rate=0.1, clf__max_depth=3, clf__n_estimators=300, vect__analyzer=char_wb, vect__ngram_range=(1, 2);, score=0.627 total time=  10.4s
# [CV 1/1] END clf=XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, gamma=None,
#               gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, predictor=None, random_state=None,
#               reg_alpha=None, reg_lambda=None, ...), clf__learning_rate=0.1, clf__max_depth=3, clf__n_estimators=300, vect__analyzer=char_wb, vect__ngram_range=(2, 2);, score=0.623 total time=   7.7s
# [CV 1/1] END clf=XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, gamma=None,
#               gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, predictor=None, random_state=None,
#               reg_alpha=None, reg_lambda=None, ...), clf__learning_rate=0.1, clf__max_depth=4, clf__n_estimators=100, vect__analyzer=word, vect__ngram_range=(1, 1);, score=0.569 total time=   0.9s
# [CV 1/1] END clf=XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, gamma=None,
#               gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, predictor=None, random_state=None,
#               reg_alpha=None, reg_lambda=None, ...), clf__learning_rate=0.1, clf__max_depth=4, clf__n_estimators=100, vect__analyzer=word, vect__ngram_range=(1, 2);, score=0.567 total time=   2.2s
# [CV 1/1] END clf=XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, gamma=None,
#               gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, predictor=None, random_state=None,
#               reg_alpha=None, reg_lambda=None, ...), clf__learning_rate=0.1, clf__max_depth=4, clf__n_estimators=100, vect__analyzer=word, vect__ngram_range=(2, 2);, score=0.473 total time=   1.3s
# [CV 1/1] END clf=XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, gamma=None,
#               gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, predictor=None, random_state=None,
#               reg_alpha=None, reg_lambda=None, ...), clf__learning_rate=0.1, clf__max_depth=4, clf__n_estimators=100, vect__analyzer=char, vect__ngram_range=(1, 1);, score=0.474 total time=   1.6s
# [CV 1/1] END clf=XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, gamma=None,
#               gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, predictor=None, random_state=None,
#               reg_alpha=None, reg_lambda=None, ...), clf__learning_rate=0.1, clf__max_depth=4, clf__n_estimators=100, vect__analyzer=char, vect__ngram_range=(1, 2);, score=0.590 total time=   5.0s
# [CV 1/1] END clf=XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, gamma=None,
#               gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, predictor=None, random_state=None,
#               reg_alpha=None, reg_lambda=None, ...), clf__learning_rate=0.1, clf__max_depth=4, clf__n_estimators=100, vect__analyzer=char, vect__ngram_range=(2, 2);, score=0.583 total time=   3.8s
# [CV 1/1] END clf=XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, gamma=None,
#               gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, predictor=None, random_state=None,
#               reg_alpha=None, reg_lambda=None, ...), clf__learning_rate=0.1, clf__max_depth=4, clf__n_estimators=100, vect__analyzer=char_wb, vect__ngram_range=(1, 1);, score=0.468 total time=   2.0s
# [CV 1/1] END clf=XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, gamma=None,
#               gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, predictor=None, random_state=None,
#               reg_alpha=None, reg_lambda=None, ...), clf__learning_rate=0.1, clf__max_depth=4, clf__n_estimators=100, vect__analyzer=char_wb, vect__ngram_range=(1, 2);, score=0.595 total time=   5.6s
# [CV 1/1] END clf=XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, gamma=None,
#               gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, predictor=None, random_state=None,
#               reg_alpha=None, reg_lambda=None, ...), clf__learning_rate=0.1, clf__max_depth=4, clf__n_estimators=100, vect__analyzer=char_wb, vect__ngram_range=(2, 2);, score=0.583 total time=   4.0s
# [CV 1/1] END clf=XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, gamma=None,
#               gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, predictor=None, random_state=None,
#               reg_alpha=None, reg_lambda=None, ...), clf__learning_rate=0.1, clf__max_depth=4, clf__n_estimators=200, vect__analyzer=word, vect__ngram_range=(1, 1);, score=0.601 total time=   1.6s
# [CV 1/1] END clf=XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, gamma=None,
#               gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, predictor=None, random_state=None,
#               reg_alpha=None, reg_lambda=None, ...), clf__learning_rate=0.1, clf__max_depth=4, clf__n_estimators=200, vect__analyzer=word, vect__ngram_range=(1, 2);, score=0.599 total time=   3.5s
# [CV 1/1] END clf=XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, gamma=None,
#               gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, predictor=None, random_state=None,
#               reg_alpha=None, reg_lambda=None, ...), clf__learning_rate=0.1, clf__max_depth=4, clf__n_estimators=200, vect__analyzer=word, vect__ngram_range=(2, 2);, score=0.498 total time=   1.9s
# [CV 1/1] END clf=XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, gamma=None,
#               gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, predictor=None, random_state=None,
#               reg_alpha=None, reg_lambda=None, ...), clf__learning_rate=0.1, clf__max_depth=4, clf__n_estimators=200, vect__analyzer=char, vect__ngram_range=(1, 1);, score=0.508 total time=   2.7s
# [CV 1/1] END clf=XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, gamma=None,
#               gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, predictor=None, random_state=None,
#               reg_alpha=None, reg_lambda=None, ...), clf__learning_rate=0.1, clf__max_depth=4, clf__n_estimators=200, vect__analyzer=char, vect__ngram_range=(1, 2);, score=0.638 total time=   8.7s
# [CV 1/1] END clf=XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, gamma=None,
#               gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, predictor=None, random_state=None,
#               reg_alpha=None, reg_lambda=None, ...), clf__learning_rate=0.1, clf__max_depth=4, clf__n_estimators=200, vect__analyzer=char, vect__ngram_range=(2, 2);, score=0.626 total time=   6.7s
# [CV 1/1] END clf=XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, gamma=None,
#               gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, predictor=None, random_state=None,
#               reg_alpha=None, reg_lambda=None, ...), clf__learning_rate=0.1, clf__max_depth=4, clf__n_estimators=200, vect__analyzer=char_wb, vect__ngram_range=(1, 1);, score=0.500 total time=   3.2s
# [CV 1/1] END clf=XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, gamma=None,
#               gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, predictor=None, random_state=None,
#               reg_alpha=None, reg_lambda=None, ...), clf__learning_rate=0.1, clf__max_depth=4, clf__n_estimators=200, vect__analyzer=char_wb, vect__ngram_range=(1, 2);, score=0.633 total time=   9.4s
# [CV 1/1] END clf=XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, gamma=None,
#               gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, predictor=None, random_state=None,
#               reg_alpha=None, reg_lambda=None, ...), clf__learning_rate=0.1, clf__max_depth=4, clf__n_estimators=200, vect__analyzer=char_wb, vect__ngram_range=(2, 2);, score=0.642 total time=   7.0s
# [CV 1/1] END clf=XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, gamma=None,
#               gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, predictor=None, random_state=None,
#               reg_alpha=None, reg_lambda=None, ...), clf__learning_rate=0.1, clf__max_depth=4, clf__n_estimators=300, vect__analyzer=word, vect__ngram_range=(1, 1);, score=0.622 total time=   2.2s
# [CV 1/1] END clf=XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, gamma=None,
#               gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, predictor=None, random_state=None,
#               reg_alpha=None, reg_lambda=None, ...), clf__learning_rate=0.1, clf__max_depth=4, clf__n_estimators=300, vect__analyzer=word, vect__ngram_range=(1, 2);, score=0.621 total time=   4.8s
# [CV 1/1] END clf=XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, gamma=None,
#               gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, predictor=None, random_state=None,
#               reg_alpha=None, reg_lambda=None, ...), clf__learning_rate=0.1, clf__max_depth=4, clf__n_estimators=300, vect__analyzer=word, vect__ngram_range=(2, 2);, score=0.504 total time=   2.6s
# [CV 1/1] END clf=XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, gamma=None,
#               gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, predictor=None, random_state=None,
#               reg_alpha=None, reg_lambda=None, ...), clf__learning_rate=0.1, clf__max_depth=4, clf__n_estimators=300, vect__analyzer=char, vect__ngram_range=(1, 1);, score=0.528 total time=   3.9s
# [CV 1/1] END clf=XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, gamma=None,
#               gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=None,
# ...
#     estimator.fit(X_train, y_train, **fit_params)
#   File "d:\Users\rando\anaconda3\lib\site-packages\sklearn\pipeline.py", line 346, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "d:\Users\rando\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1306, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "d:\Users\rando\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 443, in _check_solver
#     raise ValueError("Solver %s supports only 'l2' or 'none' penalties, "
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# [CV 1/1] END clf=LogisticRegression(), clf__C=10.0, clf__penalty=l1, vect__analyzer=word, vect__ngram_range=(1, 2);, score=nan total time=   0.7s
# d:\Users\rando\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "d:\Users\rando\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "d:\Users\rando\anaconda3\lib\site-packages\sklearn\pipeline.py", line 346, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "d:\Users\rando\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1306, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "d:\Users\rando\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 443, in _check_solver
#     raise ValueError("Solver %s supports only 'l2' or 'none' penalties, "
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# [CV 1/1] END clf=LogisticRegression(), clf__C=10.0, clf__penalty=l1, vect__analyzer=word, vect__ngram_range=(2, 2);, score=nan total time=   0.5s
# d:\Users\rando\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "d:\Users\rando\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "d:\Users\rando\anaconda3\lib\site-packages\sklearn\pipeline.py", line 346, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "d:\Users\rando\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1306, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "d:\Users\rando\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 443, in _check_solver
#     raise ValueError("Solver %s supports only 'l2' or 'none' penalties, "
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# [CV 1/1] END clf=LogisticRegression(), clf__C=10.0, clf__penalty=l1, vect__analyzer=char, vect__ngram_range=(1, 1);, score=nan total time=   0.3s
# d:\Users\rando\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "d:\Users\rando\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "d:\Users\rando\anaconda3\lib\site-packages\sklearn\pipeline.py", line 346, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "d:\Users\rando\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1306, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "d:\Users\rando\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 443, in _check_solver
#     raise ValueError("Solver %s supports only 'l2' or 'none' penalties, "
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# [CV 1/1] END clf=LogisticRegression(), clf__C=10.0, clf__penalty=l1, vect__analyzer=char, vect__ngram_range=(1, 2);, score=nan total time=   1.0s
# d:\Users\rando\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "d:\Users\rando\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "d:\Users\rando\anaconda3\lib\site-packages\sklearn\pipeline.py", line 346, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "d:\Users\rando\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1306, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "d:\Users\rando\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 443, in _check_solver
#     raise ValueError("Solver %s supports only 'l2' or 'none' penalties, "
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# [CV 1/1] END clf=LogisticRegression(), clf__C=10.0, clf__penalty=l1, vect__analyzer=char, vect__ngram_range=(2, 2);, score=nan total time=   0.6s
# d:\Users\rando\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "d:\Users\rando\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "d:\Users\rando\anaconda3\lib\site-packages\sklearn\pipeline.py", line 346, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "d:\Users\rando\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1306, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "d:\Users\rando\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 443, in _check_solver
#     raise ValueError("Solver %s supports only 'l2' or 'none' penalties, "
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# [CV 1/1] END clf=LogisticRegression(), clf__C=10.0, clf__penalty=l1, vect__analyzer=char_wb, vect__ngram_range=(1, 1);, score=nan total time=   0.7s
# d:\Users\rando\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "d:\Users\rando\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "d:\Users\rando\anaconda3\lib\site-packages\sklearn\pipeline.py", line 346, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "d:\Users\rando\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1306, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "d:\Users\rando\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 443, in _check_solver
#     raise ValueError("Solver %s supports only 'l2' or 'none' penalties, "
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# [CV 1/1] END clf=LogisticRegression(), clf__C=10.0, clf__penalty=l1, vect__analyzer=char_wb, vect__ngram_range=(1, 2);, score=nan total time=   1.5s
# d:\Users\rando\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "d:\Users\rando\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "d:\Users\rando\anaconda3\lib\site-packages\sklearn\pipeline.py", line 346, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "d:\Users\rando\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1306, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "d:\Users\rando\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 443, in _check_solver
#     raise ValueError("Solver %s supports only 'l2' or 'none' penalties, "
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# [CV 1/1] END clf=LogisticRegression(), clf__C=10.0, clf__penalty=l1, vect__analyzer=char_wb, vect__ngram_range=(2, 2);, score=nan total time=   0.8s
# d:\Users\rando\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 1/1] END clf=LogisticRegression(), clf__C=10.0, clf__penalty=l2, vect__analyzer=word, vect__ngram_range=(1, 1);, score=0.715 total time=   0.8s
# d:\Users\rando\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 1/1] END clf=LogisticRegression(), clf__C=10.0, clf__penalty=l2, vect__analyzer=word, vect__ngram_range=(1, 2);, score=0.724 total time=   2.8s
# d:\Users\rando\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 1/1] END clf=LogisticRegression(), clf__C=10.0, clf__penalty=l2, vect__analyzer=word, vect__ngram_range=(2, 2);, score=0.633 total time=   2.1s
# [CV 1/1] END clf=LogisticRegression(), clf__C=10.0, clf__penalty=l2, vect__analyzer=char, vect__ngram_range=(1, 1);, score=0.417 total time=   0.4s
# d:\Users\rando\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 1/1] END clf=LogisticRegression(), clf__C=10.0, clf__penalty=l2, vect__analyzer=char, vect__ngram_range=(1, 2);, score=0.622 total time=   1.5s
# d:\Users\rando\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 1/1] END clf=LogisticRegression(), clf__C=10.0, clf__penalty=l2, vect__analyzer=char, vect__ngram_range=(2, 2);, score=0.625 total time=   1.0s
# [CV 1/1] END clf=LogisticRegression(), clf__C=10.0, clf__penalty=l2, vect__analyzer=char_wb, vect__ngram_range=(1, 1);, score=0.419 total time=   0.9s
# d:\Users\rando\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [CV 1/1] END clf=LogisticRegression(), clf__C=10.0, clf__penalty=l2, vect__analyzer=char_wb, vect__ngram_range=(1, 2);, score=0.624 total time=   2.0s
# d:\Users\rando\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# d:\Users\rando\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:922: UserWarning: One or more of the test scores are non-finite: [0.69255151 0.7281106  0.67189729 ... 0.41944709 0.62355658 0.62395118]
#   warnings.warn(
# [CV 1/1] END clf=LogisticRegression(), clf__C=10.0, clf__penalty=l2, vect__analyzer=char_wb, vect__ngram_range=(2, 2);, score=0.624 total time=   1.3s
# GridSearchCV(cv=PredefinedSplit(test_fold=array([-1, -1, ...,  0,  0])),
#              estimator=Pipeline(steps=[('vect', TfidfVectorizer()),
#                                        ('clf', MultinomialNB())]),
#              param_grid=[{'clf__alpha': [0.1, 1.0, 10.0],
#                           'vect__analyzer': ['word', 'char', 'char_wb'],
#                           'vect__ngram_range': [(1, 1), (1, 2), (2, 2)]},
#                          {'clf': [XGBClassifier(base_score=None, booster=None,
#                                                 callbacks=None,
#                                                 colsample_byle...
#                           'clf__min_samples_leaf': [1, 2, 3],
#                           'clf__min_samples_split': [2, 3, 4],
#                           'clf__n_estimators': [100, 200, 300],
#                           'vect__analyzer': ['word', 'char', 'char_wb'],
#                           'vect__ngram_range': [(1, 1), (1, 2), (2, 2)]},
#                          {'clf': [LogisticRegression()],
#                           'clf__C': [0.1, 1.0, 10.0],
#                           'clf__penalty': ['l1', 'l2'],
#                           'vect__analyzer': ['word', 'char', 'char_wb'],
#                           'vect__ngram_range': [(1, 1), (1, 2), (2, 2)]}],
#              scoring='f1', verbose=3)

# %%
gs.best_params_
# Out:
# {'clf__alpha': 0.1, 'vect__analyzer': 'word', 'vect__ngram_range': (1, 2)}

# %%
gs.best_score_
# Out:
# 0.728110599078341

# %%
svc_pipeline = Pipeline([('vect', TfidfVectorizer()),('clf', SVC())])

svc_params = {
        'vect__ngram_range': [(1, 1), (1, 2), (2, 2)],
        'vect__analyzer': ['word', 'char', 'char_wb'],
        'clf__kernel': ['poly', 'rbf'],
        # 'clf__degree': [2, 3, 4],
        # 'clf__C': [0.1, 1.0, 10.0],
    }

svc_gs = GridSearchCV(svc_pipeline, svc_params, cv=ps, scoring='f1',verbose=3)

# %%
svc_gs.fit(X, y)
# Out:
# Fitting 1 folds for each of 18 candidates, totalling 18 fits
# [CV 1/1] END clf__kernel=poly, vect__analyzer=word, vect__ngram_range=(1, 1);, score=0.444 total time= 1.8min
# [CV 1/1] END clf__kernel=poly, vect__analyzer=word, vect__ngram_range=(1, 2);, score=0.324 total time= 3.1min
# [CV 1/1] END clf__kernel=poly, vect__analyzer=word, vect__ngram_range=(2, 2);, score=0.315 total time= 2.6min
# [CV 1/1] END clf__kernel=poly, vect__analyzer=char, vect__ngram_range=(1, 1);, score=0.537 total time=  25.3s
# [CV 1/1] END clf__kernel=poly, vect__analyzer=char, vect__ngram_range=(1, 2);, score=0.695 total time= 5.0min
# [CV 1/1] END clf__kernel=poly, vect__analyzer=char, vect__ngram_range=(2, 2);, score=0.688 total time= 7.1min
# [CV 1/1] END clf__kernel=poly, vect__analyzer=char_wb, vect__ngram_range=(1, 1);, score=0.479 total time=  20.7s
# [CV 1/1] END clf__kernel=poly, vect__analyzer=char_wb, vect__ngram_range=(1, 2);, score=0.680 total time= 3.6min
# [CV 1/1] END clf__kernel=poly, vect__analyzer=char_wb, vect__ngram_range=(2, 2);, score=0.689 total time= 7.2min
# [CV 1/1] END clf__kernel=rbf, vect__analyzer=word, vect__ngram_range=(1, 1);, score=0.727 total time= 1.3min
# [CV 1/1] END clf__kernel=rbf, vect__analyzer=word, vect__ngram_range=(1, 2);, score=0.716 total time= 1.7min
# [CV 1/1] END clf__kernel=rbf, vect__analyzer=word, vect__ngram_range=(2, 2);, score=0.601 total time= 1.6min
# [CV 1/1] END clf__kernel=rbf, vect__analyzer=char, vect__ngram_range=(1, 1);, score=0.494 total time=  18.8s
# [CV 1/1] END clf__kernel=rbf, vect__analyzer=char, vect__ngram_range=(1, 2);, score=0.673 total time= 2.6min
# [CV 1/1] END clf__kernel=rbf, vect__analyzer=char, vect__ngram_range=(2, 2);, score=0.693 total time= 4.1min
# [CV 1/1] END clf__kernel=rbf, vect__analyzer=char_wb, vect__ngram_range=(1, 1);, score=0.448 total time=  19.2s
# [CV 1/1] END clf__kernel=rbf, vect__analyzer=char_wb, vect__ngram_range=(1, 2);, score=0.663 total time= 2.4min
# [CV 1/1] END clf__kernel=rbf, vect__analyzer=char_wb, vect__ngram_range=(2, 2);, score=0.693 total time= 3.4min
# GridSearchCV(cv=PredefinedSplit(test_fold=array([-1, -1, ...,  0,  0])),
#              estimator=Pipeline(steps=[('vect', TfidfVectorizer()),
#                                        ('clf', SVC())]),
#              param_grid={'clf__kernel': ['poly', 'rbf'],
#                          'vect__analyzer': ['word', 'char', 'char_wb'],
#                          'vect__ngram_range': [(1, 1), (1, 2), (2, 2)]},
#              scoring='f1', verbose=3)

# %%
svc_gs.best_estimator_
# Out:
# Pipeline(steps=[('vect', TfidfVectorizer()), ('clf', SVC())])

# %%
svc_gs.best_score_
# Out:
# 0.7268588770864947

# %%
svc = Pipeline([('vect', TfidfVectorizer(analyzer='word', ngram_range=(1, 2))),('clf', SVC(kernel='rbf'))])
svc.fit(train_preprocessed_text, y_train)
# Out:
# Pipeline(steps=[('vect', TfidfVectorizer(ngram_range=(1, 2))), ('clf', SVC())])

# %%
f1_score(y_test, svc.predict(test_preprocessed_text))
# Out:
# 0.715925394548063

# %% [markdown]
# # Data Re-Preprocessing

# %% [markdown]
# ## Normalize

# %%
def build_alay_dict():
    df = pd.read_csv('https://raw.githubusercontent.com/nasalsabila/kamus-alay/master/colloquial-indonesian-lexicon.csv')
    return dict(zip(df['slang'], df['formal']))

def translate_alay(input_string, alay_dict):
    string_splitted = input_string.split(" ")
    for i in range(len(string_splitted)):
        if(string_splitted[i] in alay_dict):
            string_splitted[i] = alay_dict[string_splitted[i]]
    return ' '.join(string_splitted)

# %%
alay_dict = build_alay_dict()
train_normalized = train_preprocessed_text.apply(lambda x: translate_alay(x, alay_dict))
dev_normalized = dev_preprocessed_text.apply(lambda x: translate_alay(x, alay_dict))
test_normalized = test_preprocessed_text.apply(lambda x: translate_alay(x, alay_dict))

# %%
nb = Pipeline([('vect', TfidfVectorizer(analyzer='word',ngram_range=(1,2))),('clf', MultinomialNB(alpha=0.1))])
nb.fit(train_normalized, y_train)
# Out:
# Pipeline(steps=[('vect', TfidfVectorizer(ngram_range=(1, 2))),
#                 ('clf', MultinomialNB(alpha=0.1))])

# %%
f1_score(y_dev, nb.predict(dev_normalized))
# Out:
# 0.7243243243243244

# %%
svm = Pipeline([('vect', TfidfVectorizer(analyzer='word',ngram_range=(1,1))),('clf', SVC(kernel='rbf'))])
svm.fit(train_normalized, y_train)
# Out:
# Pipeline(steps=[('vect', TfidfVectorizer()), ('clf', SVC())])

# %%
f1_score(y_dev, svm.predict(dev_normalized))
# Out:
# 0.7246811702925732

# %% [markdown]
# ## Handle imbalance

# %%
# undersampling
def undersampling(text_series, labels, random_state=42):
    result_text_series = pd.Series(dtype='object')
    result_labels = np.array([])
    # value counts
    value_counts = np.unique(labels, return_counts=True)
    # get the label with minimum value
    min_label = value_counts[0][np.argmin(value_counts[1])]
    # print(value_counts)
    # print(min_label)
    # append the text with min label (and also to label np array)
    result_text_series = result_text_series.append(text_series[labels == min_label])
    result_labels = np.append(result_labels, labels[labels == min_label])
    # number of samples that label is min_label
    min_label_count = value_counts[1][min_label]
    # print(min_label_count)
    # resample the other labels
    for label in value_counts[0]:
        if label != min_label:
            # resample the text
            resampled_text = text_series[labels == label].sample(n=min_label_count, random_state=random_state)
            resampled_label = labels[resampled_text.index]
            # append the text with min label (and also to label np array)
            result_text_series = result_text_series.append(resampled_text)
            result_labels = np.append(result_labels, resampled_label)
    return result_text_series.reset_index(drop=True), result_labels

# %%
undersampled_train, undersampled_label = undersampling(train_preprocessed_text, y_train)

# %%
nb = Pipeline([('vect', TfidfVectorizer(analyzer='word',ngram_range=(1,2))),('clf', MultinomialNB(alpha=0.1))])
nb.fit(undersampled_train, undersampled_label)
# Out:
# Pipeline(steps=[('vect', TfidfVectorizer(ngram_range=(1, 2))),
#                 ('clf', MultinomialNB(alpha=0.1))])

# %%
f1_score(y_dev, nb.predict(dev_normalized))
# Out:
# 0.5336016096579477

# %%
svm = Pipeline([('vect', TfidfVectorizer(analyzer='word',ngram_range=(1,1))),('clf', SVC(kernel='rbf'))])
svm.fit(undersampled_train, undersampled_label)
# Out:
# Pipeline(steps=[('vect', TfidfVectorizer()), ('clf', SVC())])

# %%
f1_score(y_dev, svm.predict(dev_normalized))
# Out:
# 0.628992628992629

# %% [markdown]
# # Try Word2Vec

# %%
import gensim
from gensim.models import Word2Vec

# %% [markdown]
# ## CBOW

# %%
# Create CBOW model
cbow = gensim.models.Word2Vec(train_preprocessed_text, min_count = 1, window = 5, vector_size = 1000)

# %% [markdown]
# # Skip gram

# %%
# Create Skip Gram model
skipgram = gensim.models.Word2Vec(train_preprocessed_text, min_count = 1, window = 5, sg = 1, vector_size = 1000)

# %% [markdown]
# ## Usage

# %%
def get_vector(word, model):
    try:
        return model.wv[word]
    except:
        return np.zeros(1000)

# %%
# create train dataset
# cbow
train_cbow = np.array([np.mean([get_vector(word, cbow) for word in sentence.split()], axis=0) for sentence in train_preprocessed_text])
# skipgram
train_skipgram = np.array([np.mean([get_vector(word, skipgram) for word in sentence.split()], axis=0) for sentence in train_preprocessed_text])

# %%
w2v_svm = Pipeline([('clf', SVC(kernel='rbf'))])
w2v_svm.fit(train_cbow, y_train)
# Out:
# Pipeline(steps=[('clf', SVC())])

# %%
dev_cbow = np.array([np.mean([get_vector(word, cbow) for word in sentence.split()], axis=0) for sentence in dev_preprocessed_text])
dev_skipgram = np.array([np.mean([get_vector(word, skipgram) for word in sentence.split()], axis=0) for sentence in dev_preprocessed_text])

# %%
f1_score(y_dev, w2v_svm.predict(dev_cbow))
# Out:
# 0.1839572192513369

# %% [markdown]
# ## GridSearch with Word2Vec

# %%
parameters2 = [
    {
        'clf__C': [0.1, 1.0, 10.0],
    },
    {
        'clf': [XGBClassifier()],
        'clf__max_depth': [3, 4, 5],
        'clf__learning_rate': [0.1, 0.2, 0.3],
        'clf__n_estimators': [100, 200, 300],
    },
    {
        'clf': [DecisionTreeClassifier()],
        'clf__max_depth': [3, 4, 5],
        'clf__min_samples_split': [2, 3, 4],
        'clf__min_samples_leaf': [1, 2, 3],
    },
    {
        'clf': [RandomForestClassifier()],
        'clf__max_depth': [3, 4, 5],
        'clf__min_samples_split': [2, 3, 4],
        'clf__min_samples_leaf': [1, 2, 3],
        'clf__n_estimators': [100, 200, 300],
    },
    {
        'clf': [LogisticRegression()],
        'clf__penalty': ['l1', 'l2'],
        'clf__C': [0.1, 1.0, 10.0],
    },
]

# %%
train_fold = [-1 for _ in range(len(train_preprocessed_text))]
dev_fold = [0 for _ in range(len(dev_preprocessed_text))]
ps = PredefinedSplit(test_fold=np.concatenate([train_fold, dev_fold]))

Xcbow = np.concatenate([train_cbow, dev_cbow])
ycbow = np.concatenate([y_train, y_dev])

# %%
Xskipgram = np.concatenate([train_skipgram, dev_skipgram])
yskipgram = np.concatenate([y_train, y_dev])

# %%
gs_cbow = GridSearchCV(Pipeline([('clf', SVC(kernel='rbf'))]), parameters2, cv=ps, scoring='f1', n_jobs=-1, verbose=2)
gs_cbow.fit(Xcbow, ycbow)
# Out:
# Fitting 1 folds for each of 144 candidates, totalling 144 fits
# d:\Users\rando\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:378: FitFailedWarning:
# 3 fits failed out of a total of 144.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 3 fits failed with the following error:
# Traceback (most recent call last):
#   File "d:\Users\rando\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "d:\Users\rando\anaconda3\lib\site-packages\sklearn\pipeline.py", line 382, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "d:\Users\rando\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1091, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "d:\Users\rando\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 61, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# d:\Users\rando\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:953: UserWarning: One or more of the test scores are non-finite: [0.16312849 0.18395722 0.19496855 0.20675105 0.20572641 0.20464135
#  0.20689655 0.20253165 0.19661734 0.20696938 0.19595314 0.20106952
#  0.20234292 0.20042194 0.19957983 0.19181034 0.19320594 0.18790497
#  0.19429778 0.18783351 0.19201726 0.19871795 0.18770227 0.19721329
#  0.19616205 0.19271949 0.19078242 0.19119227 0.19548872 0.19914347
#  0.17570499 0.17570499 0.17570499 0.17570499 0.17570499 0.17570499
#  0.17570499 0.17570499 0.17570499 0.1709212  0.1709212  0.1709212
#  0.1709212  0.1709212  0.1709212  0.1709212  0.1709212  0.1709212
#  0.18338727 0.18338727 0.18338727 0.18338727 0.18338727 0.18318966
#  0.18338727 0.18338727 0.18338727 0.18579235 0.18122271 0.18021978
#  0.18360656 0.18933624 0.18756816 0.18181818 0.17582418 0.18201754
#  0.1760176  0.19213974 0.17743702 0.18458198 0.1760176  0.18181818
#  0.18518519 0.18518519 0.18777293 0.17782656 0.18201754 0.18400876
#  0.18538713 0.17982456 0.18201754 0.17943107 0.18579235 0.18558952
#  0.19423693 0.18162162 0.18709677 0.19334049 0.18985976 0.1875
#  0.19271949 0.19396552 0.19098712 0.19006479 0.19292605 0.18924731
#  0.19402985 0.19465241 0.18534483 0.19119227 0.1963714  0.18574514
#  0.19595314 0.18142549 0.18945102 0.20021299 0.19527897 0.18669528
#  0.19098712 0.18709677 0.18729817 0.20464135 0.20295983 0.20063358
#  0.19724284 0.20295983 0.20740741 0.19724284 0.1970339  0.20274551
#  0.2010582  0.205074   0.19512195 0.20545073 0.20189274 0.2010582
#  0.20399579 0.19831224 0.19978746 0.20442571 0.20169851 0.20920502
#  0.19852165 0.20631579 0.19724284 0.19382322 0.20820189 0.1989418
#         nan 0.03265306        nan 0.11166253        nan 0.15384615]
#   warnings.warn(
# GridSearchCV(cv=PredefinedSplit(test_fold=array([-1, -1, ...,  0,  0])),
#              estimator=Pipeline(steps=[('clf', SVC())]), n_jobs=-1,
#              param_grid=[{'clf__C': [0.1, 1.0, 10.0]},
#                          {'clf': [XGBClassifier(base_score=None, booster=None,
#                                                 callbacks=None,
#                                                 colsample_bylevel=None,
#                                                 colsample_bynode=None,
#                                                 colsample_bytree=None,
#                                                 early_stopping_rounds=None,
#                                                 enable_categorical=False,
#                                                 eval_metr...
#                           'clf__min_samples_leaf': [1, 2, 3],
#                           'clf__min_samples_split': [2, 3, 4]},
#                          {'clf': [RandomForestClassifier(max_depth=5,
#                                                          min_samples_leaf=3,
#                                                          n_estimators=300)],
#                           'clf__max_depth': [3, 4, 5],
#                           'clf__min_samples_leaf': [1, 2, 3],
#                           'clf__min_samples_split': [2, 3, 4],
#                           'clf__n_estimators': [100, 200, 300]},
#                          {'clf': [LogisticRegression()],
#                           'clf__C': [0.1, 1.0, 10.0],
#                           'clf__penalty': ['l1', 'l2']}],
#              scoring='f1', verbose=2)

# %%
gs_cbow.best_params_
# Out:
# {'clf': RandomForestClassifier(max_depth=5, min_samples_leaf=3, n_estimators=300),
#  'clf__max_depth': 5,
#  'clf__min_samples_leaf': 3,
#  'clf__min_samples_split': 2,
#  'clf__n_estimators': 300}

# %%
gs_cbow.best_score_
# Out:
# 0.20920502092050208

# %%
gs_skipgram = GridSearchCV(Pipeline([('clf', SVC(kernel='rbf'))]), parameters2, cv=ps, scoring='f1', n_jobs=-1, verbose=2)
gs_skipgram.fit(Xskipgram, yskipgram)
# Out:
# Fitting 1 folds for each of 144 candidates, totalling 144 fits
# d:\Users\rando\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:378: FitFailedWarning:
# 3 fits failed out of a total of 144.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 3 fits failed with the following error:
# Traceback (most recent call last):
#   File "d:\Users\rando\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "d:\Users\rando\anaconda3\lib\site-packages\sklearn\pipeline.py", line 382, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "d:\Users\rando\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 1091, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "d:\Users\rando\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py", line 61, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# d:\Users\rando\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:953: UserWarning: One or more of the test scores are non-finite: [0.14367161 0.17887931 0.18490967 0.20234292 0.18933624 0.18358531
#  0.19935691 0.1910828  0.19148936 0.19181034 0.19341126 0.19210245
#  0.19109663 0.18843683 0.18843683 0.18996798 0.19532909 0.1875
#  0.19532909 0.19109663 0.18695652 0.19721329 0.19320594 0.19375673
#  0.18763326 0.18494624 0.18655098 0.18530351 0.18299247 0.18458198
#  0.24485798 0.24485798 0.24485798 0.24485798 0.24485798 0.24485798
#  0.24485798 0.24485798 0.24485798 0.22937626 0.22937626 0.22937626
#  0.22937626 0.22937626 0.22937626 0.22937626 0.22937626 0.22937626
#  0.21325052 0.21325052 0.21325052 0.21302999 0.21325052 0.21325052
#  0.21325052 0.2134715  0.21325052 0.17218543 0.16629712 0.16666667
#  0.17035398 0.16814159 0.17073171 0.17161716 0.16648169 0.16666667
#  0.16741071 0.16462736 0.16888889 0.16107383 0.1760176  0.16611296
#  0.16407982 0.16997792 0.16907675 0.16629712 0.16703786 0.16666667
#  0.17073171 0.16629712 0.16685206 0.17943107 0.16499443 0.16666667
#  0.17218543 0.16960352 0.16979052 0.16703297 0.17161716 0.17142857
#  0.17199559 0.16960352 0.16740088 0.16941694 0.16556291 0.17343578
#  0.1754386  0.17563117 0.16941694 0.16556291 0.17362637 0.16556291
#  0.16941694 0.1712404  0.17161716 0.1679558  0.17142857 0.16556291
#  0.16979052 0.16960352 0.16941694 0.19139785 0.18924731 0.18965517
#  0.18965517 0.18534483 0.19763695 0.18985976 0.19098712 0.18729817
#  0.1875     0.18614719 0.18534483 0.18924731 0.18554477 0.18965517
#  0.18729817 0.18594595 0.18924731 0.18122977 0.18122977 0.18398268
#  0.19139785 0.18729817 0.19506967 0.19334049 0.18965517 0.19139785
#         nan 0.                nan 0.01668985        nan 0.09860936]
#   warnings.warn(
# GridSearchCV(cv=PredefinedSplit(test_fold=array([-1, -1, ...,  0,  0])),
#              estimator=Pipeline(steps=[('clf', SVC())]), n_jobs=-1,
#              param_grid=[{'clf__C': [0.1, 1.0, 10.0]},
#                          {'clf': [XGBClassifier(base_score=None, booster=None,
#                                                 callbacks=None,
#                                                 colsample_bylevel=None,
#                                                 colsample_bynode=None,
#                                                 colsample_bytree=None,
#                                                 early_stopping_rounds=None,
#                                                 enable_categorical=False,
#                                                 eval_metr...
#                           'clf__min_samples_leaf': [1, 2, 3],
#                           'clf__min_samples_split': [2, 3, 4]},
#                          {'clf': [RandomForestClassifier(max_depth=5,
#                                                          min_samples_leaf=3,
#                                                          n_estimators=300)],
#                           'clf__max_depth': [3, 4, 5],
#                           'clf__min_samples_leaf': [1, 2, 3],
#                           'clf__min_samples_split': [2, 3, 4],
#                           'clf__n_estimators': [100, 200, 300]},
#                          {'clf': [LogisticRegression()],
#                           'clf__C': [0.1, 1.0, 10.0],
#                           'clf__penalty': ['l1', 'l2']}],
#              scoring='f1', verbose=2)

# %%
gs_skipgram.best_params_
# Out:
# {'clf': DecisionTreeClassifier(max_depth=3),
#  'clf__max_depth': 3,
#  'clf__min_samples_leaf': 1,
#  'clf__min_samples_split': 2}

# %%
gs_skipgram.best_score_
# Out:
# 0.24485798237022527

# %% [markdown]
# # Conclusion
#
# Kesimpulannya adalah, yang terbaik adalah menggunakan TF-IDF Vectorizer dan Mulinomial Naive Bayes dengan hasil validasi f1 0.7281

# %%
nb = Pipeline([('vect', TfidfVectorizer(analyzer='word',ngram_range=(1,2))),('clf', MultinomialNB(alpha=0.1))])
nb.fit(train_preprocessed_text, y_train)
# Out:
# Pipeline(steps=[('vect', TfidfVectorizer(ngram_range=(1, 2))),
#                 ('clf', MultinomialNB(alpha=0.1))])

# %%
# classification report
from sklearn.metrics import classification_report
print(classification_report(y_test, nb.predict(test_preprocessed_text)))
print("F1 score (micro avg): ", f1_score(y_test, nb.predict(test_preprocessed_text)))
print("F1 score (macro avg): ", f1_score(y_test, nb.predict(test_preprocessed_text), average='macro'))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.94      0.92      2093
#            1       0.80      0.67      0.73       707
#
#     accuracy                           0.87      2800
#    macro avg       0.85      0.81      0.82      2800
# weighted avg       0.87      0.87      0.87      2800
#
# F1 score (micro avg):  0.728110599078341
# F1 score (macro avg):  0.8228733544484306
